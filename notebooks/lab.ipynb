# %% [markdown]
# # Wikipedia

# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
import inspect

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.append(parentdir)
sys.path.append("../")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sources.wikipedia.extractors import uruguay as uy
from sources.wikipedia.transformers.locations import uruguay as tuy
from sources.wikipedia.app import ETLWikipediaHandler as etl

# %%
import pandas as pd

# %%
df = uy.extract_municipalities(url=uy.MUNICIPALITIES_URL)
df
# Out:
#          department              municipality   population      surface  \
# 0           Artigas             Baltasar Brum        2608     754,0 km²
# 1           Artigas               Bella Unión      18 406     547,0 km²
# 2           Artigas           Tomás Gomensoro        2902     804,5 km²
# 3         Canelones                18 de Mayo      21 371      11,0 km²
# 4         Canelones          Aguas Corrientes        1728      51,5 km²
# ..              ...                       ...          ...          ...
# 120  Treinta_y_Tres  General Enrique Martínez  (sin datos)  (sin datos)
# 121  Treinta_y_Tres                    Rincón  (sin datos)  (sin datos)
# 122  Treinta_y_Tres     Santa Clara de Olimar        2485     482,4 km²
# 123  Treinta_y_Tres                   Vergara        4064     622,5 km²
# 124  Treinta_y_Tres                Villa Sara  (sin datos)  (sin datos)
#
#                      mayor   creation
# 0    Juan Marticorena (PN) 2010-03-01
# 1    William Cresseri (PN) 2010-03-01
# 2     Federico Arbiza (PN) 2010-03-01
# 3     Adriana Sánchez (FA) 2013-03-02
# 4     Marcelo Delgado (FA) 2010-03-01
# ..                     ...        ...
# 120             Nidia Vera 2017-12-02
# 121       Eduardo Gonzales 2017-12-02
# 122  Pablo Echevarría (PN) 2010-03-01
# 123     José González (PN) 2010-03-01
# 124       Analía Larrañaga 2017-12-02
#
# [125 rows x 6 columns]

# %%
country = "Uruguay"

# %%
(
    summary,
    history,
    divisions, 
    municipalities
) = uy.fetch_data(country)
# Out:
# From census 2011

# %%
from IPython.display import display
from rapidfuzz.fuzz import token_sort_ratio as tsr

# %%
display(divisions)
display(municipalities)
# Out:
#         department                 capital  area_km2  area_mi2  population
# 0       Montevideo              Montevideo       530       200     1319108
# 1        Canelones               Canelones      4536      1751      520187
# 2        Maldonado               Maldonado      4793      1851      164300
# 3            Salto                   Salto     14163      5468      124878
# 4          Colonia  Colonia del Sacramento      6106      2358      123203
# 5         Paysandú                Paysandú     13922      5375      113124
# 6         San José        San José de Mayo      4992      1927      108309
# 7           Rivera                  Rivera      9370      3620      103493
# 8       Tacuarembó              Tacuarembó     15438      5961       90053
# 9      Cerro Largo                    Melo     13648      5270       84698
# 10         Soriano                Mercedes      9008      3478       82595
# 11         Artigas                 Artigas     11928      4605       73378
# 12           Rocha                   Rocha     10551      4074       68088
# 13         Florida                 Florida     10417      4022       67048
# 14       Lavalleja                   Minas     10016      3867       58815
# 15         Durazno                 Durazno     11643      4495       57088
# 16       Río Negro             Fray Bentos      9282      3584       54765
# 17  Treinta y Tres          Treinta y Tres      9529      3679       48134
# 18          Flores                Trinidad      5144      1986       25050
#          department              municipality   population      surface  \
# 0           Artigas             Baltasar Brum        2608     754,0 km²
# 1           Artigas               Bella Unión      18 406     547,0 km²
# 2           Artigas           Tomás Gomensoro        2902     804,5 km²
# 3         Canelones                18 de Mayo      21 371      11,0 km²
# 4         Canelones          Aguas Corrientes        1728      51,5 km²
# ..              ...                       ...          ...          ...
# 120  Treinta_y_Tres  General Enrique Martínez  (sin datos)  (sin datos)
# 121  Treinta_y_Tres                    Rincón  (sin datos)  (sin datos)
# 122  Treinta_y_Tres     Santa Clara de Olimar        2485     482,4 km²
# 123  Treinta_y_Tres                   Vergara        4064     622,5 km²
# 124  Treinta_y_Tres                Villa Sara  (sin datos)  (sin datos)
#
#                      mayor   creation
# 0    Juan Marticorena (PN) 2010-03-01
# 1    William Cresseri (PN) 2010-03-01
# 2     Federico Arbiza (PN) 2010-03-01
# 3     Adriana Sánchez (FA) 2013-03-02
# 4     Marcelo Delgado (FA) 2010-03-01
# ..                     ...        ...
# 120             Nidia Vera 2017-12-02
# 121       Eduardo Gonzales 2017-12-02
# 122  Pablo Echevarría (PN) 2010-03-01
# 123     José González (PN) 2010-03-01
# 124       Analía Larrañaga 2017-12-02
#
# [125 rows x 6 columns]

# %%
dfd = divisions.copy()
dfm = municipalities.copy()

# %%
dfd["_muni_dept"] = dfm["department"].copy().unique()
dfd
# Out:
#         department                 capital  area_km2  area_mi2  population  \
# 0       Montevideo              Montevideo       530       200     1319108
# 1        Canelones               Canelones      4536      1751      520187
# 2        Maldonado               Maldonado      4793      1851      164300
# 3            Salto                   Salto     14163      5468      124878
# 4          Colonia  Colonia del Sacramento      6106      2358      123203
# 5         Paysandú                Paysandú     13922      5375      113124
# 6         San José        San José de Mayo      4992      1927      108309
# 7           Rivera                  Rivera      9370      3620      103493
# 8       Tacuarembó              Tacuarembó     15438      5961       90053
# 9      Cerro Largo                    Melo     13648      5270       84698
# 10         Soriano                Mercedes      9008      3478       82595
# 11         Artigas                 Artigas     11928      4605       73378
# 12           Rocha                   Rocha     10551      4074       68088
# 13         Florida                 Florida     10417      4022       67048
# 14       Lavalleja                   Minas     10016      3867       58815
# 15         Durazno                 Durazno     11643      4495       57088
# 16       Río Negro             Fray Bentos      9282      3584       54765
# 17  Treinta y Tres          Treinta y Tres      9529      3679       48134
# 18          Flores                Trinidad      5144      1986       25050
#
#         _muni_dept
# 0          Artigas
# 1        Canelones
# 2      Cerro_Largo
# 3          Colonia
# 4          Durazno
# 5           Flores
# 6          Florida
# 7        Lavalleja
# 8        Maldonado
# 9       Montevideo
# 10        Paysandu
# 11       Rio_Negro
# 12          Rivera
# 13           Rocha
# 14           Salto
# 15        San_Jose
# 16         Soriano
# 17      Tacuarembo
# 18  Treinta_y_Tres

# %%
def tokenize(row, pairs):
    for p in pairs:
        token = tsr(row["department"], p)
        if token > 85:
            return p
    return pd.NA

# %%
dfd["_dept"] = dfd.apply(lambda row: tokenize(row, dfd["_muni_dept"].to_list()), axis=1)
dfd
# Out:
#         department                 capital  area_km2  area_mi2  population  \
# 0       Montevideo              Montevideo       530       200     1319108
# 1        Canelones               Canelones      4536      1751      520187
# 2        Maldonado               Maldonado      4793      1851      164300
# 3            Salto                   Salto     14163      5468      124878
# 4          Colonia  Colonia del Sacramento      6106      2358      123203
# 5         Paysandú                Paysandú     13922      5375      113124
# 6         San José        San José de Mayo      4992      1927      108309
# 7           Rivera                  Rivera      9370      3620      103493
# 8       Tacuarembó              Tacuarembó     15438      5961       90053
# 9      Cerro Largo                    Melo     13648      5270       84698
# 10         Soriano                Mercedes      9008      3478       82595
# 11         Artigas                 Artigas     11928      4605       73378
# 12           Rocha                   Rocha     10551      4074       68088
# 13         Florida                 Florida     10417      4022       67048
# 14       Lavalleja                   Minas     10016      3867       58815
# 15         Durazno                 Durazno     11643      4495       57088
# 16       Río Negro             Fray Bentos      9282      3584       54765
# 17  Treinta y Tres          Treinta y Tres      9529      3679       48134
# 18          Flores                Trinidad      5144      1986       25050
#
#         _muni_dept           _dept
# 0          Artigas      Montevideo
# 1        Canelones       Canelones
# 2      Cerro_Largo       Maldonado
# 3          Colonia           Salto
# 4          Durazno         Colonia
# 5           Flores        Paysandu
# 6          Florida        San_Jose
# 7        Lavalleja          Rivera
# 8        Maldonado      Tacuarembo
# 9       Montevideo     Cerro_Largo
# 10        Paysandu         Soriano
# 11       Rio_Negro         Artigas
# 12          Rivera           Rocha
# 13           Rocha         Florida
# 14           Salto       Lavalleja
# 15        San_Jose         Durazno
# 16         Soriano       Rio_Negro
# 17      Tacuarembo  Treinta_y_Tres
# 18  Treinta_y_Tres          Flores

# %%
dfm = dfm.rename(columns={"department":"_dept"})
dfm
# Out:
#               _dept              municipality   population      surface  \
# 0           Artigas             Baltasar Brum        2608     754,0 km²
# 1           Artigas               Bella Unión      18 406     547,0 km²
# 2           Artigas           Tomás Gomensoro        2902     804,5 km²
# 3         Canelones                18 de Mayo      21 371      11,0 km²
# 4         Canelones          Aguas Corrientes        1728      51,5 km²
# ..              ...                       ...          ...          ...
# 120  Treinta_y_Tres  General Enrique Martínez  (sin datos)  (sin datos)
# 121  Treinta_y_Tres                    Rincón  (sin datos)  (sin datos)
# 122  Treinta_y_Tres     Santa Clara de Olimar        2485     482,4 km²
# 123  Treinta_y_Tres                   Vergara        4064     622,5 km²
# 124  Treinta_y_Tres                Villa Sara  (sin datos)  (sin datos)
#
#                      mayor   creation
# 0    Juan Marticorena (PN) 2010-03-01
# 1    William Cresseri (PN) 2010-03-01
# 2     Federico Arbiza (PN) 2010-03-01
# 3     Adriana Sánchez (FA) 2013-03-02
# 4     Marcelo Delgado (FA) 2010-03-01
# ..                     ...        ...
# 120             Nidia Vera 2017-12-02
# 121       Eduardo Gonzales 2017-12-02
# 122  Pablo Echevarría (PN) 2010-03-01
# 123     José González (PN) 2010-03-01
# 124       Analía Larrañaga 2017-12-02
#
# [125 rows x 6 columns]

# %%
df = (
    dfm
    .merge(dfd, how="left", on="_dept")
    .rename(
        columns={
            "population_x": "municipality_ppl",
            "surface": "municipality_area_km2",
            "creation": "municipality_creation_date",
            "capital": "province_capital",
            "department": "province",
            "area_km2": "province_area_km2",
            "population_y": "province_ppl"
        }
    )
    .assign(
        country_code="UY",
    )
    .drop(
        columns=["_dept", "mayor", "area_mi2", "_muni_dept"],
        axis=1
    )
)
df["province_code"] = (
    df["province"]
    .str.replace(r"A|a|E|e|I|i|O|o|U|u|\s+", "", regex=True)
    .str.upper()[:4]
    .str.replace("Í", "I", regex=False)
)
df
# Out:
#                  municipality municipality_ppl municipality_area_km2  \
# 0               Baltasar Brum            2608              754,0 km²
# 1                 Bella Unión          18 406              547,0 km²
# 2             Tomás Gomensoro            2902              804,5 km²
# 3                  18 de Mayo          21 371               11,0 km²
# 4            Aguas Corrientes            1728               51,5 km²
# ..                        ...              ...                   ...
# 120  General Enrique Martínez      (sin datos)           (sin datos)
# 121                    Rincón      (sin datos)           (sin datos)
# 122     Santa Clara de Olimar            2485              482,4 km²
# 123                   Vergara            4064              622,5 km²
# 124                Villa Sara      (sin datos)           (sin datos)
#
#     municipality_creation_date        province province_capital  \
# 0                   2010-03-01         Artigas          Artigas
# 1                   2010-03-01         Artigas          Artigas
# 2                   2010-03-01         Artigas          Artigas
# 3                   2013-03-02       Canelones        Canelones
# 4                   2010-03-01       Canelones        Canelones
# ..                         ...             ...              ...
# 120                 2017-12-02  Treinta y Tres   Treinta y Tres
# 121                 2017-12-02  Treinta y Tres   Treinta y Tres
# 122                 2010-03-01  Treinta y Tres   Treinta y Tres
# 123                 2010-03-01  Treinta y Tres   Treinta y Tres
# 124                 2017-12-02  Treinta y Tres   Treinta y Tres
#
#      province_area_km2  province_ppl country_code province_code
# 0                11928         73378           UY          RTGS
# 1                11928         73378           UY          RTGS
# 2                11928         73378           UY          RTGS
# 3                 4536        520187           UY         CNLNS
# 4                 4536        520187           UY           NaN
# ..                 ...           ...          ...           ...
# 120               9529         48134           UY           NaN
# 121               9529         48134           UY           NaN
# 122               9529         48134           UY           NaN
# 123               9529         48134           UY           NaN
# 124               9529         48134           UY           NaN
#
# [125 rows x 10 columns]

# %%
import re

# %%
df[df["province_code"].notna()]
# Out:
#       municipality municipality_ppl municipality_area_km2  \
# 0    Baltasar Brum            2608              754,0 km²
# 1      Bella Unión          18 406              547,0 km²
# 2  Tomás Gomensoro            2902              804,5 km²
# 3       18 de Mayo          21 371               11,0 km²
#
#   municipality_creation_date   province province_capital  province_area_km2  \
# 0                 2010-03-01    Artigas          Artigas              11928
# 1                 2010-03-01    Artigas          Artigas              11928
# 2                 2010-03-01    Artigas          Artigas              11928
# 3                 2013-03-02  Canelones        Canelones               4536
#
#    province_ppl country_code province_code
# 0         73378           UY          RTGS
# 1         73378           UY          RTGS
# 2         73378           UY          RTGS
# 3        520187           UY         CNLNS

# %%
dft
# Out:
#    country_id  country country_code provinces  municipalities language  \
# 0    81190644  Uruguay           UY        19             123  Spanish
#
#    population
# 0     3286314

# %%
for p in df["province"].unique():
    print(
        re.sub(r"A|a|E|e|I|i|O|o|U|u|\s+", "", p).upper()[:4].replace("Í", "I")
    )
# Out:
# RTGS
# CNLN
# CRRL
# CLN
# DRZN
# FLRS
# FLRD
# LVLL
# MLDN
# MNTV
# PYSN
# RING
# RVR
# RCH
# SLT
# SNJS
# SRN
# TCRM
# TRNT

# %%
dft.columns
# Out:
# Index(['municipality', 'municipality_ppl', 'municipality_area_km2',
#        'municipality_creation_date', 'province', 'province_capital',
#        'province_area_km2', 'province_ppl', 'country_code',
#        'municipality_code', 'country_id', 'province_id', 'municipality_id'],
#       dtype='object')

# %%
dft = tuy.transform(divisions, municipalities)
dft
# Out:
#                  municipality municipality_ppl municipality_area_km2  \
# 0               Baltasar Brum             2608                 754.0
# 1                 Bella Unión            18406                 547.0
# 2             Tomás Gomensoro             2902                 804.5
# 3                  18 de Mayo            21371                  11.0
# 4            Aguas Corrientes             1728                  51.5
# ..                        ...              ...                   ...
# 120  General Enrique Martínez             <NA>                  <NA>
# 121                    Rincón             <NA>                  <NA>
# 122     Santa Clara de Olimar             2485                 482.4
# 123                   Vergara             4064                 622.5
# 124                Villa Sara             <NA>                  <NA>
#
#     municipality_creation_date        province province_capital  \
# 0                   2010-03-01         Artigas          Artigas
# 1                   2010-03-01         Artigas          Artigas
# 2                   2010-03-01         Artigas          Artigas
# 3                   2013-03-02       Canelones        Canelones
# 4                   2010-03-01       Canelones        Canelones
# ..                         ...             ...              ...
# 120                 2017-12-02  Treinta y Tres   Treinta y Tres
# 121                 2017-12-02  Treinta y Tres   Treinta y Tres
# 122                 2010-03-01  Treinta y Tres   Treinta y Tres
# 123                 2010-03-01  Treinta y Tres   Treinta y Tres
# 124                 2017-12-02  Treinta y Tres   Treinta y Tres
#
#      province_area_km2  province_ppl country_code municipality_code  \
# 0                11928         73378           UY        UY_RTGS_00
# 1                11928         73378           UY        UY_RTGS_01
# 2                11928         73378           UY        UY_RTGS_02
# 3                 4536        520187           UY        UY_CNLN_00
# 4                 4536        520187           UY        UY_CNLN_01
# ..                 ...           ...          ...               ...
# 120               9529         48134           UY        UY_TRNT_01
# 121               9529         48134           UY        UY_TRNT_02
# 122               9529         48134           UY        UY_TRNT_03
# 123               9529         48134           UY        UY_TRNT_04
# 124               9529         48134           UY        UY_TRNT_05
#
#      country_id  province_id  municipality_id
# 0      81190644      9870182         46737365
# 1      81190644      9870182         63322545
# 2      81190644      9870182         41724416
# 3      81190644     39954974         62882303
# 4      81190644     39954974         65631475
# ..          ...          ...              ...
# 120    81190644     71518810         83100131
# 121    81190644     71518810         45090488
# 122    81190644     71518810         60703856
# 123    81190644     71518810         71641628
# 124    81190644     71518810         22772767
#
# [125 rows x 13 columns]

# %%
dft["province_code"] = dft["municipality_code"].apply(lambda c: c.split("_")[1])
dft
dft.drop_duplicates(subset=["province"])[["province", "province_code"]]
# Out:
#            province province_code
# 0           Artigas          RTGS
# 3         Canelones          CNLN
# 33      Cerro Largo          CRRL
# 48          Colonia           CLN
# 59          Durazno          DRZN
# 61           Flores          FLRS
# 62          Florida          FLRD
# 65        Lavalleja          LVLL
# 69        Maldonado          MLDN
# 77       Montevideo          MNTV
# 85         Paysandú          PYSN
# 92        Río Negro          RING
# 95           Rivera           RVR
# 98            Rocha           RCH
# 102           Salto           SLT
# 108        San José          SNJS
# 112         Soriano           SRN
# 116      Tacuarembó          TCRM
# 119  Treinta y Tres          TRNT

# %%
country_df, province_df, municipality_df = tuy.transform_location(divisions, municipalities, normalize=True)
display(country_df)
display(province_df)
display(municipality_df)
# Out:
#    country_id country_name country_capital country_code country_provinces  \
# 0    81190644      Uruguay      Montevideo           UY                19
#
#    country_municipalities country_language  country_population
# 0                     123          Spanish             3286314
#     province_id   province_name        province_capital province_code  \
# 0       9870182         Artigas                 Artigas          RTGS
# 1      39954974       Canelones               Canelones          CNLN
# 2      10100291     Cerro Largo                    Melo          CRRL
# 3       5146549         Colonia  Colonia del Sacramento           CLN
# 4      57644730         Durazno                 Durazno          DRZN
# 5      37190418          Flores                Trinidad          FLRS
# 6       8304410         Florida                 Florida          FLRD
# 7      87420148       Lavalleja                   Minas          LVLL
# 8      66576982       Maldonado               Maldonado          MLDN
# 9      74830974      Montevideo              Montevideo          MNTV
# 10     87272203        Paysandú                Paysandú          PYSN
# 11     75619306       Río Negro             Fray Bentos          RING
# 12     63589751          Rivera                  Rivera           RVR
# 13     71660940           Rocha                   Rocha           RCH
# 14      5360955           Salto                   Salto           SLT
# 15     83226347        San José        San José de Mayo          SNJS
# 16     24985419         Soriano                Mercedes           SRN
# 17     28681826      Tacuarembó              Tacuarembó          TCRM
# 18     71518810  Treinta y Tres          Treinta y Tres          TRNT
#
#     province_population  province_area  country_id
# 0                 73378          11928    81190644
# 1                520187           4536    81190644
# 2                 84698          13648    81190644
# 3                123203           6106    81190644
# 4                 57088          11643    81190644
# 5                 25050           5144    81190644
# 6                 67048          10417    81190644
# 7                 58815          10016    81190644
# 8                164300           4793    81190644
# 9               1319108            530    81190644
# 10               113124          13922    81190644
# 11                54765           9282    81190644
# 12               103493           9370    81190644
# 13                68088          10551    81190644
# 14               124878          14163    81190644
# 15               108309           4992    81190644
# 16                82595           9008    81190644
# 17                90053          15438    81190644
# 18                48134           9529    81190644
#      municipality_id         municipality_name municipality_code  \
# 0           46737365             Baltasar Brum        UY_RTGS_00
# 1           63322545               Bella Unión        UY_RTGS_01
# 2           41724416           Tomás Gomensoro        UY_RTGS_02
# 3           62882303                18 de Mayo        UY_CNLN_00
# 4           65631475          Aguas Corrientes        UY_CNLN_01
# ..               ...                       ...               ...
# 120         83100131  General Enrique Martínez        UY_TRNT_01
# 121         45090488                    Rincón        UY_TRNT_02
# 122         60703856     Santa Clara de Olimar        UY_TRNT_03
# 123         71641628                   Vergara        UY_TRNT_04
# 124         22772767                Villa Sara        UY_TRNT_05
#
#     municipality_creation_date municipality_population municipality_area  \
# 0                   2010-03-01                    2608             754.0
# 1                   2010-03-01                   18406             547.0
# 2                   2010-03-01                    2902             804.5
# 3                   2013-03-02                   21371              11.0
# 4                   2010-03-01                    1728              51.5
# ..                         ...                     ...               ...
# 120                 2017-12-02                    <NA>              <NA>
# 121                 2017-12-02                    <NA>              <NA>
# 122                 2010-03-01                    2485             482.4
# 123                 2010-03-01                    4064             622.5
# 124                 2017-12-02                    <NA>              <NA>
#
#      province_id  country_id
# 0        9870182    81190644
# 1        9870182    81190644
# 2        9870182    81190644
# 3       39954974    81190644
# 4       39954974    81190644
# ..           ...         ...
# 120     71518810    81190644
# 121     71518810    81190644
# 122     71518810    81190644
# 123     71518810    81190644
# 124     71518810    81190644
#
# [125 rows x 8 columns]
