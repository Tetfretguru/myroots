# %% [markdown]
# # Wikipedia

# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
import inspect

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.append(parentdir)
sys.path.append("../")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sources.wikipedia.extractors import uruguay as uy

# %%
import pandas as pd

# %%
country = "Uruguay"

# %%
(
    summary,
    history,
    divisions, 
    municipalities
) = uy.fetch_data(country)
# Out:
# From census 2011

# %%
summary
# Out:
# {'Official language': 'Spanish[a]Uruguayan Sign Language (LSU)[b]',
#  'Regional and Indigenous languages': 'Mbyá Guaraní\nPlautdietsch\nPortuñol\nRussian\nUruguayan Portuguese',
#  'Ethnic groups  (2011)': '87.7% White4.6% Black2.4% Indigenous0.2% East Asian[note 1]5.1% Other / Unspecified',
#  'Religion  (2020)': '57.0% Christianity41.5% No religion1.5% Other / Unspecified',
#  'Demonym(s)': 'Uruguayan',
#  'Government': 'Unitary presidential republic',
#  'President': 'Luis Lacalle Pou',
#  'Vice President': 'Beatriz Argimón',
#  'Legislature': 'General Assembly',
#  'Upper house': 'Senate',
#  'Lower house': 'Chamber of Representatives',
#  'Admitted to the UN': '18 December 1945',
#  'Total': '64.283 billion (80th)',
#  'Water (%)': '1.5',
#  'Density': '19.8/km2 (51.3/sq mi) (99th)',
#  'GDP (PPP)': '2022 estimate',
#  'Per capita': '18,083 (49th)',
#  'GDP (nominal)': '2022 estimate',
#  'Gini (2019)': '39.7medium',
#  'HDI (2019)': '0.817very high · 55th',
#  'Currency': 'Uruguayan peso (UYU)',
#  'Time zone': 'UTC−3 (UYT)',
#  'Date format': 'dd/mm/yyyy',
#  'Driving side': 'right',
#  'Calling code': '598',
#  'ISO 3166 code': 'UY',
#  'Internet TLD': 'uy',
#  'Population': {'2011 census': '3,390,077',
#   '2019 estimate': '3,518,552 (132nd)'},
#  'Capital and largest city': 'Montevideo34°53′S 56°10′W\ufeff / \ufeff34.883°S 56.167°W\ufeff / -34.883; -56.167',
#  'Independance': {'Declared': '25 August 1825',
#   'First Constitution': '18 July 1830',
#   'Recognized': '27 August 1828'}}

# %%
summary_df = pd.DataFrame.from_dict(summary, orient="index").T 
summary_df = summary_df.rename(columns={col:f"_{col.replace(' ', '').lower()}" for col in summary_df.columns})
summary_df["country_capital_geolocation"] = summary_df["_capitalandlargestcity"].apply(lambda x: re.findall(r"\d+\°\d+.[A-Z]|\d+\.\d+\°[A-Z]|\-\d+\.\d+", x))
# Out:
#                             _officiallanguage  \
# 0  Spanish[a]Uruguayan Sign Language (LSU)[b]
#
#                      _regionalandindigenouslanguages  \
# 0  Mbyá Guaraní\nPlautdietsch\nPortuñol\nRussi...
#
#                                  _ethnicgroups(2011)  \
# 0  87.7% White4.6% Black2.4% Indigenous0.2% East ...
#
#                                      _religion(2020) _demonym(s)  \
# 0  57.0% Christianity41.5% No religion1.5% Other ...   Uruguayan
#
#                      _government        _president    _vicepresident  \
# 0  Unitary presidential republic  Luis Lacalle Pou  Beatriz Argimón
#
#        _legislature _upperhouse  ...             _currency    _timezone  \
# 0  General Assembly      Senate  ...  Uruguayan peso (UYU)  UTC−3 (UYT)
#
#   _dateformat _drivingside _callingcode _iso3166code _internettld  \
# 0  dd/mm/yyyy        right          598           UY           uy
#
#                                          _population  \
# 0  {'2011 census': '3,390,077', '2019 estimate': ...
#
#                               _capitalandlargestcity  \
# 0  Montevideo34°53′S 56°10′W﻿ / ﻿34.883°S 56.167°...
#
#                                        _independance
# 0  {'Declared': '25 August 1825', 'First Constitu...
#
# [1 rows x 30 columns]

# %%
import re

# %%
s = summary_df["_capitalandlargestcity"][0]
s
# Out:
# 'Montevideo34°53′S 56°10′W\ufeff / \ufeff34.883°S 56.167°W\ufeff / -34.883; -56.167'

# %%
re.findall(r"\d+\°\d+.[A-Z]|\d+\.\d+\°[A-Z]|\-\d+\.\d+", s)
# Out:
# ['34°53′S', '56°10′W', '34.883°S', '56.167°W', '-34.883', '-56.167']

# %% [markdown]
# # Recipe

# %%
# Wikipedia
from sources.wikipedia.extractors.uruguay import fetch_data as uy_extract
from sources.wikipedia.transformers.uruguay.country_main import create_tables as uy_transform

country = "uruguay"
_, _, divisions, municipalities = uy_extract(country=country)
country_df, province_df, subdivision_df = uy_transform(divisions, municipalities)
# Out:
# From census 2011

# %%
country_df
# Out:
#    country_id country_name country_capital country_code country_provinces  \
# 0    81190644      Uruguay      Montevideo           UY                19
#
#    country_municipalities country_language  country_population
# 0                     123          Spanish             3286314

# %%
province_df
# Out:
#     province_id   province_name        province_capital province_code  \
# 0       9870182         Artigas                 Artigas          RTGS
# 1      39954974       Canelones               Canelones          CNLN
# 2      10100291     Cerro Largo                    Melo          CRRL
# 3       5146549         Colonia  Colonia del Sacramento           CLN
# 4      57644730         Durazno                 Durazno          DRZN
# 5      37190418          Flores                Trinidad          FLRS
# 6       8304410         Florida                 Florida          FLRD
# 7      87420148       Lavalleja                   Minas          LVLL
# 8      66576982       Maldonado               Maldonado          MLDN
# 9      74830974      Montevideo              Montevideo          MNTV
# 10     87272203        Paysandú                Paysandú          PYSN
# 11     75619306       Río Negro             Fray Bentos          RING
# 12     63589751          Rivera                  Rivera           RVR
# 13     71660940           Rocha                   Rocha           RCH
# 14      5360955           Salto                   Salto           SLT
# 15     83226347        San José        San José de Mayo          SNJS
# 16     24985419         Soriano                Mercedes           SRN
# 17     28681826      Tacuarembó              Tacuarembó          TCRM
# 18     71518810  Treinta y Tres          Treinta y Tres          TRNT
#
#     province_population  province_area  country_id
# 0                 73378          11928    81190644
# 1                520187           4536    81190644
# 2                 84698          13648    81190644
# 3                123203           6106    81190644
# 4                 57088          11643    81190644
# 5                 25050           5144    81190644
# 6                 67048          10417    81190644
# 7                 58815          10016    81190644
# 8                164300           4793    81190644
# 9               1319108            530    81190644
# 10               113124          13922    81190644
# 11                54765           9282    81190644
# 12               103493           9370    81190644
# 13                68088          10551    81190644
# 14               124878          14163    81190644
# 15               108309           4992    81190644
# 16                82595           9008    81190644
# 17                90053          15438    81190644
# 18                48134           9529    81190644

# %%
subdivision_df
# Out:
#      municipality_id         municipality_name municipality_code  \
# 0           46737365             Baltasar Brum        UY_RTGS_00
# 1           63322545               Bella Unión        UY_RTGS_01
# 2           41724416           Tomás Gomensoro        UY_RTGS_02
# 3           62882303                18 de Mayo        UY_CNLN_00
# 4           65631475          Aguas Corrientes        UY_CNLN_01
# ..               ...                       ...               ...
# 120         83100131  General Enrique Martínez        UY_TRNT_01
# 121         45090488                    Rincón        UY_TRNT_02
# 122         60703856     Santa Clara de Olimar        UY_TRNT_03
# 123         71641628                   Vergara        UY_TRNT_04
# 124         22772767                Villa Sara        UY_TRNT_05
#
#     municipality_creation_date municipality_population municipality_area  \
# 0                   2010-03-01                    2608             754.0
# 1                   2010-03-01                   18406             547.0
# 2                   2010-03-01                    2902             804.5
# 3                   2013-03-02                   21371              11.0
# 4                   2010-03-01                    1728              51.5
# ..                         ...                     ...               ...
# 120                 2017-12-02                    <NA>              <NA>
# 121                 2017-12-02                    <NA>              <NA>
# 122                 2010-03-01                    2485             482.4
# 123                 2010-03-01                    4064             622.5
# 124                 2017-12-02                    <NA>              <NA>
#
#      province_id  country_id
# 0        9870182    81190644
# 1        9870182    81190644
# 2        9870182    81190644
# 3       39954974    81190644
# 4       39954974    81190644
# ..           ...         ...
# 120     71518810    81190644
# 121     71518810    81190644
# 122     71518810    81190644
# 123     71518810    81190644
# 124     71518810    81190644
#
# [125 rows x 8 columns]

# %%
province_df.merge(subdivision_df, on="province_id", how="left").query("province_name == 'Canelones'")
# Out:
#     province_id province_name province_capital province_code  \
# 3      39954974     Canelones        Canelones          CNLN
# 4      39954974     Canelones        Canelones          CNLN
# 5      39954974     Canelones        Canelones          CNLN
# 6      39954974     Canelones        Canelones          CNLN
# 7      39954974     Canelones        Canelones          CNLN
# 8      39954974     Canelones        Canelones          CNLN
# 9      39954974     Canelones        Canelones          CNLN
# 10     39954974     Canelones        Canelones          CNLN
# 11     39954974     Canelones        Canelones          CNLN
# 12     39954974     Canelones        Canelones          CNLN
# 13     39954974     Canelones        Canelones          CNLN
# 14     39954974     Canelones        Canelones          CNLN
# 15     39954974     Canelones        Canelones          CNLN
# 16     39954974     Canelones        Canelones          CNLN
# 17     39954974     Canelones        Canelones          CNLN
# 18     39954974     Canelones        Canelones          CNLN
# 19     39954974     Canelones        Canelones          CNLN
# 20     39954974     Canelones        Canelones          CNLN
# 21     39954974     Canelones        Canelones          CNLN
# 22     39954974     Canelones        Canelones          CNLN
# 23     39954974     Canelones        Canelones          CNLN
# 24     39954974     Canelones        Canelones          CNLN
# 25     39954974     Canelones        Canelones          CNLN
# 26     39954974     Canelones        Canelones          CNLN
# 27     39954974     Canelones        Canelones          CNLN
# 28     39954974     Canelones        Canelones          CNLN
# 29     39954974     Canelones        Canelones          CNLN
# 30     39954974     Canelones        Canelones          CNLN
# 31     39954974     Canelones        Canelones          CNLN
# 32     39954974     Canelones        Canelones          CNLN
#
#     province_population  province_area  country_id_x  municipality_id  \
# 3                520187           4536      81190644         62882303
# 4                520187           4536      81190644         65631475
# 5                520187           4536      81190644         27320342
# 6                520187           4536      81190644         22485304
# 7                520187           4536      81190644         39954974
# 8                520187           4536      81190644         38666914
# 9                520187           4536      81190644         10458337
# 10               520187           4536      81190644         14361772
# 11               520187           4536      81190644          1687413
# 12               520187           4536      81190644         24939679
# 13               520187           4536      81190644         65876807
# 14               520187           4536      81190644         91410920
# 15               520187           4536      81190644         56167503
# 16               520187           4536      81190644         47519868
# 17               520187           4536      81190644         63029869
# 18               520187           4536      81190644         55662906
# 19               520187           4536      81190644         98452558
# 20               520187           4536      81190644         48241614
# 21               520187           4536      81190644         21972476
# 22               520187           4536      81190644         74425871
# 23               520187           4536      81190644         28027986
# 24               520187           4536      81190644         89295584
# 25               520187           4536      81190644         39239550
# 26               520187           4536      81190644         88291274
# 27               520187           4536      81190644         47185302
# 28               520187           4536      81190644         96264678
# 29               520187           4536      81190644            67864
# 30               520187           4536      81190644         35585176
# 31               520187           4536      81190644          9109152
# 32               520187           4536      81190644          6247532
#
#      municipality_name municipality_code municipality_creation_date  \
# 3           18 de Mayo        UY_CNLN_00                 2013-03-02
# 4     Aguas Corrientes        UY_CNLN_01                 2010-03-01
# 5            Atlántida        UY_CNLN_02                 2010-03-01
# 6       Barros Blancos        UY_CNLN_03                 2010-03-01
# 7            Canelones        UY_CNLN_04                 2010-03-01
# 8   Ciudad de la Costa        UY_CNLN_05                 2010-03-01
# 9     Colonia Nicolich        UY_CNLN_06                 2010-03-01
# 10       Empalme Olmos        UY_CNLN_07                 2010-03-01
# 11         La Floresta        UY_CNLN_08                 2010-03-01
# 12              La Paz        UY_CNLN_09                 2010-03-01
# 13         Las Piedras        UY_CNLN_10                 2010-03-01
# 14       Los Cerrillos        UY_CNLN_11                 2010-03-01
# 15              Migues        UY_CNLN_12                 2010-03-01
# 16              Montes        UY_CNLN_13                 2010-03-01
# 17               Pando        UY_CNLN_14                 2010-03-01
# 18    Parque del Plata        UY_CNLN_15                 2010-03-01
# 19       Paso Carrasco        UY_CNLN_16                 2010-03-01
# 20            Progreso        UY_CNLN_17                 2010-03-01
# 21             Salinas        UY_CNLN_18                 2010-03-01
# 22         San Antonio        UY_CNLN_19                 2010-03-01
# 23        San Bautista        UY_CNLN_20                 2010-03-01
# 24         San Jacinto        UY_CNLN_21                 2010-03-01
# 25           San Ramón        UY_CNLN_22                 2010-03-01
# 26         Santa Lucía        UY_CNLN_23                 2010-03-01
# 27          Santa Rosa        UY_CNLN_24                 2010-03-01
# 28               Sauce        UY_CNLN_25                 2010-03-01
# 29                Soca        UY_CNLN_26                 2010-03-01
# 30              Suárez        UY_CNLN_27                 2010-03-01
# 31                Tala        UY_CNLN_28                 2010-03-01
# 32              Toledo        UY_CNLN_29                 2010-03-01
#
#    municipality_population municipality_area  country_id_y
# 3                    21371              11.0      81190644
# 4                     1728              51.5      81190644
# 5                    10198             108.1      81190644
# 6                    29865              22.8      81190644
# 7                    27406             230.8      81190644
# 8                    91284              61.1      81190644
# 9                    14788              26.0      81190644
# 10                    6630             152.5      81190644
# 11                    8353              59.1      81190644
# 12                   20194              32.9      81190644
# 13                   62238              53.9      81190644
# 14                    7713             261.4      81190644
# 15                    3802             363.3      81190644
# 16                    1842              55.5      81190644
# 17                   32927             114.9      81190644
# 18                   11054              12.8      81190644
# 19                   20842              20.7      81190644
# 20                   14292              78.5      81190644
# 21                   23447              83.7      81190644
# 22                    3283             168.6      81190644
# 23                    3684             196.5      81190644
# 24                    6691             274.9      81190644
# 25                    8087             249.3      81190644
# 26                   18524             252.2      81190644
# 27                    6751             192.5      81190644
# 28                   13019             295.9      81190644
# 29                    3959             493.1      81190644
# 30                   18153              44.0      81190644
# 31                    9308             522.1      81190644
# 32                   18740              30.3      81190644
